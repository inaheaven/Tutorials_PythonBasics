# %%
# conda install -c conda-forge jpype1
# pip install konlpy -> java...
# pip install wordcloud
# pip install gensim
# corpus -> documents
# 불용... 특문자, 조사, 접미어... -> 품사...형용사...명사..대명사..
# wordcloud...빈도..감정.....등등... 
# Data Analsys -> Text Mining -> Code Dic
# stopwords -> is the
# punkt -> , "",.....
#import nltk
#nltk.download()
from konlpy.tag import Kkma
kkma = Kkma()
kkma.sentences("안녕하세요. 오늘은 즐거운 일요일입니다. 수고하세요.")
kkma.nouns("안녕하세요. 오늘은 즐거운 일요일입니다. 수고하세요.")
# Out:
# ['안녕', '오늘', '일요일', '수고']

# %%
kkma.pos("안녕하세요. 오늘은 즐거운 일요일입니다. 수고하세요.")
# Out:
# [('안녕', 'NNG'),
#  ('하', 'XSV'),
#  ('세요', 'EFN'),
#  ('.', 'SF'),
#  ('오늘', 'NNG'),
#  ('은', 'JX'),
#  ('즐겁', 'VA'),
#  ('ㄴ', 'ETD'),
#  ('일요일', 'NNG'),
#  ('이', 'VCP'),
#  ('ㅂ니다', 'EFN'),
#  ('.', 'SF'),
#  ('수고', 'NNG'),
#  ('하', 'XSV'),
#  ('세요', 'EFN'),
#  ('.', 'SF')]

# %%
from konlpy.tag import Hannanum
hannaum = Hannanum()

# %%
hannaum.nouns("안녕하세요. 즐거운 반갑습니다. 일요일되세요.")
hannaum.morphs("안녕하세요. 즐거운 반갑습니다. 일요일되세요.")
hannaum.pos("안녕하세요. 즐거운 반갑습니다. 일요일되세요.")
# Out:
# [('안녕', 'N'),
#  ('하', 'X'),
#  ('세', 'E'),
#  ('요', 'J'),
#  ('.', 'S'),
#  ('즐겁', 'P'),
#  ('은', 'E'),
#  ('반갑', 'P'),
#  ('습니다', 'E'),
#  ('.', 'S'),
#  ('일요일', 'N'),
#  ('되', 'X'),
#  ('세', 'E'),
#  ('요', 'J'),
#  ('.', 'S')]

# %%
from konlpy.tag import Twitter
t = Twitter()

# %%
t.nouns("한국어 분석을 시작합니다.")
# Out:
# ['한국어', '분석']

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
text = open('./alice.txt').read()
alice_mask = np.array(Image.open('./alice.png'))
stopwords = set(STOPWORDS)
stopwords.add("said")

# %%
import matplotlib.pyplot as plt

# %%
plt.Figure(figsize=(8,8))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask,
              stopwords = stopwords)
wc = wc.generate(text)
#wc.words_
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
