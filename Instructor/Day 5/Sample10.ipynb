# %%
import pandas as pd
seoul_cctv = pd.read_csv("./data/seoul_cctv.csv", encoding='utf-8')
seoul_cctv.head()
#seoul_cctv.columns
#seoul_cctv.columns[0]
seoul_cctv.rename(columns={seoul_cctv.columns[0] : "구별" }, inplace=True)
seoul_cctv
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573     78     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009     78    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# ...

# %%
PopulateSeoul = pd.read_excel("./data/populationSeoul.xls", encoding='utf-8', header=2, usecols='B, D, G, J, N')
PopulateSeoul.head()
PopulateSeoul.rename(columns={
    PopulateSeoul.columns[0] : "구별",
    PopulateSeoul.columns[1] : "인구수",
    PopulateSeoul.columns[2] : "한국인",
    PopulateSeoul.columns[3] : "외국인",
    PopulateSeoul.columns[4] : "고령자"
    },inplace=True)
PopulateSeoul
# Out:
#       구별       인구수      한국인     외국인      고령자
# 0     합계  10197604  9926968  270636  1321458
# 1    종로구    162820   153589    9231    25425
# 2     중구    133240   124312    8928    20764
# 3    용산구    244203   229456   14747    36231
# 4    성동구    311244   303380    7864    39997
# 5    광진구    372164   357211   14953    42214
# 6   동대문구    369496   354079   15417    54173
# 7    중랑구    414503   409882    4621    56774
# 8    성북구    461260   449773   11487    64692
# 9    강북구    330192   326686    3506    54813
# 10   도봉구    348646   346629    2017    51312
# 11   노원구    569384   565565    3819    71941
# 12   은평구    494388   489943    4445    72334
# 13  서대문구    327163   314982   12181    48161
# 14   마포구    389649   378566   11083    48765
# 15   양천구    479978   475949    4029    52975
# 16   강서구    603772   597248    6524    72548
# 17   구로구    447874   416487   31387    56833
# 18   금천구    255082   236353   18729    32970
# 19  영등포구    402985   368072   34913    52413
# ...

# %%
import numpy as np
data = pd.Series([1, 3, 4, np.nan, 6, 8])
data
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

data2 = pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A', 'B', 'C', 'D'])
data2
data2.columns
data2.values
data2.info
data2.describe()
data2.sort_values(by='B', ascending=False)
data2['A']
data2[0:3]
data2['20130102':'20130103']
data2.loc[dates[0], 'A']
data2.iloc[3]
# Out:
# A    2.025228
# B    1.501012
# C    0.542595
# D    1.172144
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
seoul_cctv.head()
seoul_cctv.sort_values(by='소계', ascending=True).head(3)
# Out:
#     구별   소계  2013년도 이전  2014년  2015년  2016년
# 9  도봉구  825        238    159     42    386
# 2  강북구  831        369    120    138    204
# 5  광진구  878        573     78     53    174

# %%
seoul_cctv["최근증가율"] = (seoul_cctv["2016년"] + seoul_cctv["2015년"] + seoul_cctv["2014년"]) / seoul_cctv["2013년도 이전"] * 100
seoul_cctv.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  3238       1292    430    584    932  150.619195
# 1  강동구  1010        379     99    155    377  166.490765
# 2  강북구   831        369    120    138    204  125.203252
# 3  강서구   911        388    258    184     81  134.793814
# 4  관악구  2109        846    260    390    613  149.290780

# %%
PopulateSeoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10197604  9926968  270636  1321458
# 1  종로구    162820   153589    9231    25425
# 2   중구    133240   124312    8928    20764
# 3  용산구    244203   229456   14747    36231
# 4  성동구    311244   303380    7864    39997

# %%
PopulateSeoul.drop([0], inplace=True)
PopulateSeoul
PopulateSeoul["구별"].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
PopulateSeoul[PopulateSeoul["구별"].isnull()]
#PopulateSeoul.drop([], inplace=True)
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
PopulateSeoul
PopulateSeoul["외국인비율"]  = PopulateSeoul["외국인"] / PopulateSeoul["인구수"] * 100
PopulateSeoul["고령자비율"]  = PopulateSeoul["고령자"] / PopulateSeoul["인구수"] * 100
PopulateSeoul.sort_values(by="인구수", ascending=False)
PopulateSeoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  162820  153589   9231  25425  5.669451  15.615404
# 2   중구  133240  124312   8928  20764  6.700690  15.583909
# 3  용산구  244203  229456  14747  36231  6.038828  14.836427
# 4  성동구  311244  303380   7864  39997  2.526635  12.850689
# 5  광진구  372164  357211  14953  42214  4.017852  11.342849

# %%
seoul_cctv.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  3238       1292    430    584    932  150.619195
# 1  강동구  1010        379     99    155    377  166.490765
# 2  강북구   831        369    120    138    204  125.203252
# 3  강서구   911        388    258    184     81  134.793814
# 4  관악구  2109        846    260    390    613  149.290780

# %%
result = pd.merge(seoul_cctv, PopulateSeoul, on="구별")
del result["2016년"]
del result["2015년"]
del result["2014년"]
del result["2013년도 이전"]
result.head()
# Out:
#     구별    소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0  강남구  3238  150.619195  570500  565550   4950  63167  0.867660  11.072217
# 1  강동구  1010  166.490765  453233  449019   4214  54622  0.929765  12.051638
# 2  강북구   831  125.203252  330192  326686   3506  54813  1.061806  16.600342
# 3  강서구   911  134.793814  603772  597248   6524  72548  1.080540  12.015794
# 4  관악구  2109  149.290780  525515  507203  18312  68082  3.484582  12.955291

# %%
result
# Out:
#       구별    소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0    강남구  3238  150.619195  570500  565550   4950  63167  0.867660  11.072217
# 1    강동구  1010  166.490765  453233  449019   4214  54622  0.929765  12.051638
# 2    강북구   831  125.203252  330192  326686   3506  54813  1.061806  16.600342
# 3    강서구   911  134.793814  603772  597248   6524  72548  1.080540  12.015794
# 4    관악구  2109  149.290780  525515  507203  18312  68082  3.484582  12.955291
# 5    광진구   878   53.228621  372164  357211  14953  42214  4.017852  11.342849
# 6    구로구  1884   64.973730  447874  416487  31387  56833  7.007998  12.689506
# 7    금천구  1348  100.000000  255082  236353  18729  32970  7.342345  12.925255
# 8    노원구  1566  188.929889  569384  565565   3819  71941  0.670725  12.634883
# 9    도봉구   825  246.638655  348646  346629   2017  51312  0.578524  14.717507
# 10  동대문구  1870   74.766355  369496  354079  15417  54173  4.172440  14.661322
# ...

# %%
#result.head()
#result.set_index("구별")
#import matplotlib.pyplot as plt
#plt.figure()
esult.head()
# Out:
#        소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구  3238  150.619195  570500  565550   4950  63167  0.867660  11.072217
# 강동구  1010  166.490765  453233  449019   4214  54622  0.929765  12.051638
# 강북구   831  125.203252  330192  326686   3506  54813  1.061806  16.600342
# 강서구   911  134.793814  603772  597248   6524  72548  1.080540  12.015794
# 관악구  2109  149.290780  525515  507203  18312  68082  3.484582  12.955291

# %%
import matplotlib.pyplot as plt
t = np.arange(0, 12, 0.01)
y = np.sin(t)
y1 = np.cos(t)
plt.figure(figsize=(10,6))
plt.plot(t,y, "r--", label='sin')
plt.plot(t, y1, "g^", label='cos')
plt.legend()
plt.xlabel("time")
plt.ylabel("high")
plt.title("Test Demo")
plt.grid()
plt.show()

# %%
s1 = np.random.normal(loc=0, scale=1, size=1000)
s2 = np.random.normal(loc=5, scale=0.5, size=1000)
s3 = np.random.normal(loc=10, scale=2, size=1000)

plt.figure(figsize=(10,6))
plt.plot(s1, label="s1")
plt.plot(s2, label="s2")
plt.plot(s3, label="s3")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(411)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure()
result["소계"].plot(kind="barh", grid=True, figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(result["인구수"])
