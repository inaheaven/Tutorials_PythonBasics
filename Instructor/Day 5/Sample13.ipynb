# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

url = "http://www.basketball-reference.com/draft/NBA_2014.html"

html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')
data_rows = soup.findAll('tr')[2:]

player_data = []  

for i in range(len(data_rows)): 
    player_row = []
    for td in data_rows[i].findAll('td')[2:4]:        
        player_row.append(td.getText())        
    player_data.append(player_row)
    
df = pd.DataFrame(player_data_02, columns=["Player", "College"])
df
# Out:
#                     Player                                College
# 0           Andrew Wiggins                   University of Kansas
# 1            Jabari Parker                        Duke University
# 2              Joel Embiid                   University of Kansas
# 3             Aaron Gordon                  University of Arizona
# 4               Dante Exum
# 5             Marcus Smart              Oklahoma State University
# 6            Julius Randle                 University of Kentucky
# 7             Nik Stauskas                 University of Michigan
# 8              Noah Vonleh                     Indiana University
# 9            Elfrid Payton   University of Louisiana at Lafayette
# 10          Doug McDermott                   Creighton University
# 11             Dario Saric
# 12             Zach LaVine  University of California, Los Angeles
# 13             T.J. Warren        North Carolina State University
# 14           Adreian Payne              Michigan State University
# 15            Jusuf Nurkic
# 16             James Young                 University of Kentucky
# 17             Tyler Ennis                    Syracuse University
# 18             Gary Harris              Michigan State University
# 19           Bruno Caboclo
# 20            Mitch McGary                 University of Michigan
# 21            Jordan Adams  University of California, Los Angeles
# 22             Rodney Hood                        Duke University
# 23          Shabazz Napier              University of Connecticut
# 24            Clint Capela
# 25           P.J. Hairston           University of North Carolina
# 26       Bogdan Bogdanovic
# 27             C.J. Wilcox               University of Washington
# 28            Josh Huestis                    Stanford University
# 29           Kyle Anderson  University of California, Los Angeles
# ..                     ...                                    ...
# 32           Damien Inglis
# 33          K.J. McDaniels                     Clemson University
# 34              Joe Harris                 University of Virginia
# 35        Cleanthony Early               Wichita State University
# 36          Jarnell Stokes                University of Tennessee
# 37     Johnny O'Bryant III             Louisiana State University
# 38         DeAndre Daniels              University of Connecticut
# 39       Spencer Dinwiddie                 University of Colorado
# 40            Jerami Grant                    Syracuse University
# 41      Glenn Robinson III                 University of Michigan
# 42            Nikola Jokic
# 43            Nick Johnson                  University of Arizona
# 44          Walter Tavares
# 45            Markel Brown              Oklahoma State University
# 46           Dwight Powell                    Stanford University
# 47         Jordan Clarkson                 University of Missouri
# 48              Russ Smith               University of Louisville
# 49         Lamar Patterson               University of Pittsburgh
# 50        Cameron Bairstow               University of New Mexico
# 51              Alec Brown      University of Wisconsin-Green Bay
# 52  Thanasis Antetokounmpo
# 53          Vasilije Micic
# 54      Alessandro Gentile
# 55        Nemanja Dangubic
# 56          Semaj Christon                      Xavier University
# 57        Roy Devyn Marble                     University of Iowa
# 58          Louis Labeyrie
# 59            Jordan McRae                University of Tennessee
# 60           Xavier Thames             San Diego State University
# 61          Cory Jefferson                      Baylor University
#
# [62 rows x 2 columns]
